# %%
# !git status
# Out:
# On branch master
# Your branch is up to date with 'origin/main'.
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	../../.ipynb_checkpoints/
# 	../../DataCleaning/
# 	../../Json/
# 	../
# 	../../Untitled.ipynb
# 	../../Untitled1.ipynb
# 	../../Untitled2.ipynb
# 	../../Untitled3.ipynb
# 	../../Untitled4.ipynb
# 	../../Untitled5.ipynb
# 	../../Untitled6.ipynb
# 	../../anaconda_projects/
# 	../../dsc-accessing-data-with-pandas/
# 	../../dsc-csv/
# 	../../dsc-pandas-series-and-dataframes-lab/
# 	../../dsc-pandas-series-and-dataframes/
# 	../../dsc-running-jupyter-locally-lab/
# 	../../dsc-working-with-known-json-schemas/
# 	../../test/
#
# nothing added to commit but untracked files present (use "git add" to track)
